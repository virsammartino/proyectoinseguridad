# %% [markdown]
# ### El objetivo de esta notebook es obtener los datos (principalmente ubicaciones y calidad) de los hoteles o similares

# %%
import numpy as np
import pandas as pd

# %%
alojamientos_turisticos = pd.read_csv('../Data/alojamientos-turisticos.csv')
alojamientos_turisticos.sample(3)
# Out:
#           long        lat num_registro  periodo     categoria  \
# 355 -58.383854 -34.603917          347     2019       Hosp. B
# 358 -58.424608 -34.582644          337     2019       Hosp. B
# 439 -58.389562 -34.588573      57 A/11     2019  REG DE PREST
#
#       establecimiento           telefono                         mail  \
# 355           BAHIA 2  (54 11) 4382 1780                          NaN
# 358            BRISAS          4774-0485  hotelbrisasbaires@gmail.com
# 439  MIO BUENOS AIRES  (54 11) 5295 8500  reservas@miobuenosaires.com
#
#            calle  calle_nro       barrio     comuna  codigo_postal  \
# 355  CORRIENTES        1212  San Nicolas   Comuna 1         1043.0
# 358     CHARCAS        4470      Palermo  Comuna 14         1425.0
# 439    QUINTANA         465     Recoleta   Comuna 2         1129.0
#
#     codigo_postal_argentino
# 355                C1043AAZ
# 358                C1425BNN
# 439                C1129ABA

# %%
alojamientos_turisticos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   long                     500 non-null    float64
#  1   lat                      500 non-null    float64
#  2   num_registro             501 non-null    object
#  3   periodo                  501 non-null    int64
#  4   categoria                501 non-null    object
#  5   establecimiento          501 non-null    object
#  6   telefono                 501 non-null    object
#  7   mail                     373 non-null    object
#  8   calle                    501 non-null    object
#  9   calle_nro                501 non-null    int64
#  10  barrio                   492 non-null    object
#  11  comuna                   492 non-null    object
#  12  codigo_postal            491 non-null    float64
#  13  codigo_postal_argentino  489 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 54.9+ KB

# %%
for i in alojamientos_turisticos.columns:
    print('Columna:',i)
    print(alojamientos_turisticos[i].value_counts(), '\n\n')
# Out:
# Columna: long
# -58.411678    3
# -58.383854    2
# -58.388996    2
# -58.385757    2
# -58.384393    2
#              ..
# -58.378188    1
# -58.397793    1
# -58.392003    1
# -58.440001    1
# -58.441088    1
# Name: long, Length: 494, dtype: int64
#
#
# Columna: lat
# -34.610956    3
# -34.603917    2
# -34.589997    2
# -34.589394    2
# -34.597223    2
#              ..
# -34.594176    1
# -34.570201    1
# -34.608715    1
# -34.587134    1
# -34.612066    1
# Name: lat, Length: 491, dtype: int64
#
#
# Columna: num_registro
# 209    3
# 233    2
# 229    2
# 119    2
# 208    2
#       ..
# 96     1
# 310    1
# 34     1
# 120    1
# 161    1
# Name: num_registro, Length: 479, dtype: int64
#
#
# Columna: periodo
# 2019    501
# Name: periodo, dtype: int64
#
#
# Columna: categoria
# Hosp. A         99
# Hosp. B         79
# REG DE PREST    76
# 4*              66
# 2*              46
# 3*              46
# 1*              31
# 5*              19
# APART           17
# APART 2*        16
# APART 3*         4
# APART 1*         2
# Name: categoria, dtype: int64
#
#
# Columna: establecimiento
# RICH                                                       2
# MEXICO                                                     2
# CENTRAL                                                    2
# OLLEROS                                                    2
# HISPANO ARGENTINO                                          2
#                                                           ..
# ORO APPART                                                 1
# LACROZE                                                    1
# PARK ELEGANCE UNIQUE (ex KEMPINSKI HOTEL PARK ELEGANCE)    1
# Alvear Icon Hotel                                          1
# ALCAZAR                                                    1
# Name: establecimiento, Length: 493, dtype: int64
#
#
# Columna: telefono
# 4304-3783                        2
# (54 11) 4300-7314                2
# 4611-2133                        1
# 4371-6450                        1
# (54 11 4384 8360                 1
#                                 ..
# (54 11) 4131 6464                1
# (54 11) 4342 3053                1
# (54 11) 4304-2935 - 4306-4304    1
# (54 11) 4314-8415 / 5440         1
# (54 11) 4864-5097 al 99          1
# Name: telefono, Length: 499, dtype: int64
#
#
# Columna: mail
# NO TIENE                             3
# reservas@525hotel.com                3
# reservas.bsas@hotels-unique.com      3
# info@sienahotel.com.ar               1
# kilcahostel@hotmail.com              1
#                                     ..
# reservas@rochesterclassic.com.ar     1
# luey@arnet.com.ar                    1
# reservas@imaginehotelboutique.com    1
# info@amerian.com                     1
# resevas@icarosuites.com              1
# Name: mail, Length: 367, dtype: int64
#
#
# Columna: calle
# AV. DE MAYO     18
# CORRIENTES      16
# SUIPACHA        14
# B. MITRE        13
# RIVADAVIA       11
#                 ..
# BORGES           1
# MANSILLA         1
# CIUDADELA        1
# BULNES           1
# GUIDO            1
# Name: calle, Length: 186, dtype: int64
#
#
# Columna: calle_nro
# 857     3
# 474     3
# 24      3
# 2047    2
# 1564    2
#        ..
# 4770    1
# 675     1
# 1545    1
# 2727    1
# 3072    1
# Name: calle_nro, Length: 461, dtype: int64
#
#
# Columna: barrio
# San Nicolas          100
# Balvanera             74
# Palermo               57
# Monserrat             57
# Retiro                51
# Recoleta              40
# Constitucion          32
# San Telmo             13
# Almagro               11
# Flores                10
# Colegiales             8
# Belgrano               7
# Nu\u00f1ez             6
# San Cristobal          5
# Caballito              3
# Puerto Madero          3
# Barracas               2
# Villa Urquiza          2
# Floresta               2
# Villa Crespo           2
# Chacarita              2
# Parque Chas            1
# Paternal               1
# Boedo                  1
# Villa Del Parque       1
# Villa Gral. Mitre      1
# Name: barrio, dtype: int64
#
#
# Columna: comuna
# Comuna 1     256
# Comuna 3      79
# Comuna 14     57
# Comuna 2      40
# Comuna 13     21
# Comuna 5      12
# Comuna 7      10
# Comuna 15      6
# Comuna 6       3
# Comuna 11      2
# Comuna 12      2
# Comuna 10      2
# Comuna 4       2
# Name: comuna, dtype: int64
#
#
# Columna: codigo_postal
# 1425.0    35
# 1414.0    19
# 1426.0    17
# 1008.0    13
# 1406.0    10
#           ..
# 1045.0     1
# 1055.0     1
# 1093.0     1
# 1231.0     1
# 1141.0     1
# Name: codigo_postal, Length: 151, dtype: int64
#
#
# Columna: codigo_postal_argentino
# C1136ABI    4
# C1170AAB    3
# C1031AAA    3
# C1207ABP    3
# C1069AAP    3
#            ..
# C1103ACM    1
# C1070AAK    1
# C1138ACI    1
# C1429CMR    1
# C1129ABA    1
# Name: codigo_postal_argentino, Length: 440, dtype: int64

# %%
# Nos deshacemos de columnas irrelevantes
columns_at_todrop = ['periodo','telefono','mail','codigo_postal','codigo_postal_argentino']
alojamientos_turisticos_1 = alojamientos_turisticos.drop(columns=columns_at_todrop)

# %%
alojamientos_turisticos_1.sample(5)
# Out:
#           long        lat num_registro categoria  \
# 277 -58.473749 -34.634911          214   Hosp. A
# 255 -58.423232 -34.597154          284   Hosp. A
# 131 -58.382202 -34.604724      23 A/10        4*
# 100 -58.384381 -34.594209            9        3*
# 209 -58.455561 -34.563540         5020     APART
#
#                                        establecimiento      calle  calle_nro  \
# 277                                         COSTA AZUL   ALBERDI        3327
# 255                                              ARIES    GASCON        1147
# 131                        CAESAR PARK SILVER OBELISCO   CERRITO         328
# 100                                             IMPALA  LIBERTAD        1215
# 209  APART HOTEL CABILDO SUITES (ex CABILDO SUITES ...   CABILDO        1950
#
#           barrio     comuna
# 277     Floresta  Comuna 10
# 255      Palermo  Comuna 14
# 131  San Nicolas   Comuna 1
# 100       Retiro   Comuna 1
# 209     Belgrano  Comuna 13

# %% [markdown]
# *¿Cómo podemos combinar este df con el principal?*

# %%
# Vamos a crear la columna en común con el main
alojamientos_turisticos_1['lat-lon'] = list(zip(alojamientos_turisticos_1.lat, alojamientos_turisticos_1.long))
alojamientos_turisticos_1.sample(3)
# Out:
#          long        lat num_registro categoria    establecimiento  \
# 10 -58.395648 -34.610601      70 A/12        1*       DEL CONGRESO
# 67 -58.424967 -34.578432           15        2*      PALERMO HOTEL
# 17 -58.407147 -34.612066          137        1*  HISPANO ARGENTINO
#
#            calle  calle_nro     barrio     comuna  \
# 10  H. YRIGOYEN        2064  Balvanera   Comuna 3
# 67   GODOY CRUZ        2709    Palermo  Comuna 14
# 17    CATAMARCA         167  Balvanera   Comuna 3
#
#                               lat-lon
# 10           (-34.610601, -58.395648)
# 67           (-34.578432, -58.424967)
# 17  (-34.612066, -58.407146999999995)

# %%
# Nos quedamos con las columnas más importantes
alojamientos_turisticos_2 = alojamientos_turisticos_1.loc[:,['lat-lon','categoria']]
alojamientos_turisticos_2.sample(3)
# Out:
#                                         lat-lon categoria
# 49   (-34.605734000000005, -58.383567000000006)        2*
# 342                    (-34.609266, -58.379213)   Hosp. A
# 32            (-34.609428, -58.414803000000006)        2*

# %%
# Buscamos que no haya cosas raras en el df
alojamientos_turisticos_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat-lon    501 non-null    object
#  1   categoria  501 non-null    object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
# Valores duplicados? Nos interesa en particular que las cooredanadas no se repitan
alojamientos_turisticos_2['lat-lon'].duplicated().value_counts()
# Out:
# False    497
# True       4
# Name: lat-lon, dtype: int64

# %%
# Ah mirá...
mask_alojamientos_duplicated = alojamientos_turisticos_2['lat-lon'].duplicated() == True
alojamientos_turisticos_2.loc[mask_alojamientos_duplicated]
# Out:
#                                        lat-lon categoria
# 168                   (-34.604028, -58.385757)        4*
# 276                   (-34.610956, -58.411678)   Hosp. A
# 346                   (-34.610956, -58.411678)   Hosp. B
# 355  (-34.603916999999996, -58.38385400000001)   Hosp. B

# %%
mask_alojamientos_duplicated_c = (alojamientos_turisticos_2['lat-lon'] == (-34.610956, -58.411678)) | (alojamientos_turisticos_2['lat-lon'] ==(-34.603916999999996, -58.38385400000001)) | (alojamientos_turisticos_2['lat-lon']==(-34.604028, -58.385757))
alojamientos_turisticos_2.loc[mask_alojamientos_duplicated_c]
# Out:
#                                        lat-lon categoria
# 96                    (-34.604028, -58.385757)        3*
# 168                   (-34.604028, -58.385757)        4*
# 252                   (-34.610956, -58.411678)   Hosp. A
# 276                   (-34.610956, -58.411678)   Hosp. A
# 346                   (-34.610956, -58.411678)   Hosp. B
# 354  (-34.603916999999996, -58.38385400000001)   Hosp. B
# 355  (-34.603916999999996, -58.38385400000001)   Hosp. B

# %%
# Chequeamos esas filas en el dataframe original (que tiene todas las columnas)
alojamientos_turisticos.iloc[[96,168,252,276,346,354,355],:]
# Out:
#           long        lat num_registro  periodo categoria  \
# 96  -58.385757 -34.604028      49 A/11     2019        3*
# 168 -58.385757 -34.604028      48 A/11     2019        4*
# 252 -58.411678 -34.610956          240     2019   Hosp. A
# 276 -58.411678 -34.610956          823     2019   Hosp. A
# 346 -58.411678 -34.610956          336     2019   Hosp. B
# 354 -58.383854 -34.603917          346     2019   Hosp. B
# 355 -58.383854 -34.603917          347     2019   Hosp. B
#
#                       establecimiento                  telefono  \
# 96   HOTEL IBIS BUENOS AIRES OBELISCO         (54 11) 4370-9300
# 168                           NOVOTEL  (54 11) 4370-9300 / 9500
# 252                            ALSINA         (54 11) 4931 9393
# 276                          COLONIAL    (54 11) 4931 8800/3104
# 346               2018-11-24 00:00:00                 4931-4661
# 354                           BAHIA 1                 4382-1780
# 355                           BAHIA 2         (54 11) 4382 1780
#
#                                            mail             calle  calle_nro  \
# 96                          h6502-dm1@accor.com       CORRIENTES        1344
# 168                          h6503-re@accor.com       CORRIENTES        1334
# 252                                         NaN  24 DE NOVIEMBRE          24
# 276             info@hotelcolonialbaires.com.ar  24 DE NOVIEMBRE          24
# 346                                         NaN  24 DE NOVIEMBRE          24
# 354  anelluz@hotmail.com arhotelbahia@gmail.com       CORRIENTES        1212
# 355                                         NaN       CORRIENTES        1212
#
#           barrio    comuna  codigo_postal codigo_postal_argentino
# 96   San Nicolas  Comuna 1         1043.0                C1043ABN
# 168  San Nicolas  Comuna 1         1043.0                C1043ABN
# 252    Balvanera  Comuna 3         1170.0                C1170AAB
# 276    Balvanera  Comuna 3         1170.0                C1170AAB
# 346    Balvanera  Comuna 3         1170.0                C1170AAB
# 354  San Nicolas  Comuna 1         1043.0                C1043AAZ
# 355  San Nicolas  Comuna 1         1043.0                C1043AAZ

# %%
# No sabemos a qué puede deberse las observaciones duplicadas.
# Investigamos por internet qué establecimiento está en cada una de esas direcciones y eliminamos las que no aparecen ahí
alojamientos_turisticos_3 = alojamientos_turisticos_2.drop(index=[96,252,346,355])
print('Cantidad de observaciones antes de eliminar:', alojamientos_turisticos_2.shape[0])
print('Cantidad de observaciones después de eliminar:', alojamientos_turisticos_3.shape[0])
# Out:
# Cantidad de observaciones antes de eliminar: 501
# Cantidad de observaciones después de eliminar: 497

# %% [markdown]
# # Dataframe listo para pasar: "alojamientos_turisticos_3"

# %%
alojamientos_turisticos_3
# Out:
#                                lat-lon     categoria
# 0    (-34.572421999999996, -58.430627)            1*
# 1    (-34.596496, -58.394791000000005)            1*
# 2             (-34.609331, -58.385505)            1*
# 3    (-34.615128000000006, -58.376078)            1*
# 4    (-34.617901, -58.374441000000004)            1*
# ..                                 ...           ...
# 496  (-34.616498, -58.375932999999996)  REG DE PREST
# 497   (-34.610481, -58.36198100000001)  REG DE PREST
# 498           (-34.587358, -58.429186)  REG DE PREST
# 499            (-34.61592, -58.381653)  REG DE PREST
# 500  (-34.583821, -58.428369999999994)  REG DE PREST
#
# [497 rows x 2 columns]

# %%
alojamientos_turisticos_3.info()
#obj
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat-lon    497 non-null    object
#  1   categoria  497 non-null    object
# dtypes: object(2)
# memory usage: 11.6+ KB
